# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings 
warnings.filterwarnings('ignore')

# %%
#to display all the row and columns of dataframe
pd.set_option('display.max_rows',800)
pd.set_option('display.max_columns',15)
pd.set_option('display.width',1000)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Avanthi\\Desktop\\dataset'

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0              6      148             72             35        0  33.6                     0.627   50        1
# 1              1       85             66             29        0  26.6                     0.351   31        0
# 2              8      183             64              0        0  23.3                     0.672   32        1
# 3              1       89             66             23       94  28.1                     0.167   21        0
# 4              0      137             40             35      168  43.1                     2.288   33        1
# 5              5      116             74              0        0  25.6                     0.201   30        0
# 6              3       78             50             32       88  31.0                     0.248   26        1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin         BMI  DiabetesPedigreeFunction         Age     Outcome
# count   768.000000  768.000000     768.000000     768.000000  768.000000  768.000000                768.000000  768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479   31.992578                  0.471876   33.240885    0.348958
# std       3.369578   31.972618      19.355807      15.952218  115.244002    7.884160                  0.331329   11.760232    0.476951
# min       0.000000    0.000000       0.000000       0.000000    0.000000    0.000000                  0.078000   21.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000   27.300000                  0.243750   24.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000   32.000000                  0.372500   29.000000    0.000000
# ...

# %%
# !pip install dtale

# %%
import dtale
import dtale.app as dtale_app

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-8269LFHI:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
plt.figure(figsize = (15,8))

sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
plt.figure(figsize = (15,8))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin         BMI  DiabetesPedigreeFunction         Age     Outcome
# count   768.000000  768.000000     768.000000     768.000000  768.000000  768.000000                768.000000  768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479   31.992578                  0.471876   33.240885    0.348958
# std       3.369578   31.972618      19.355807      15.952218  115.244002    7.884160                  0.331329   11.760232    0.476951
# min       0.000000    0.000000       0.000000       0.000000    0.000000    0.000000                  0.078000   21.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000   27.300000                  0.243750   24.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000   32.000000                  0.372500   29.000000    0.000000
# ...

# %%
df['Glucose'] = np.where(df['Glucose']==0, 117, df['Glucose'])

# %%
df['BloodPressure'] = np.where(df['BloodPressure']==0, 72, df['BloodPressure'])

# %%
df['SkinThickness'] = np.where(df['SkinThickness']==0, 23, df['SkinThickness'])

# %%
df['Insulin'] = np.where(df['Insulin']==0, 30.5, df['Insulin'])

# %%
df['BMI'] = np.where(df['BMI']==0, 32, df['BMI'])

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin         BMI  DiabetesPedigreeFunction         Age     Outcome
# count   768.000000  768.000000     768.000000     768.000000  768.000000  768.000000                768.000000  768.000000  768.000000
# mean      3.845052  121.656250      72.386719      27.334635   94.652344   32.450911                  0.471876   33.240885    0.348958
# std       3.369578   30.438286      12.096642       9.229014  105.547598    6.875366                  0.331329   11.760232    0.476951
# min       0.000000   44.000000      24.000000       7.000000   14.000000   18.200000                  0.078000   21.000000    0.000000
# 25%       1.000000   99.750000      64.000000      23.000000   30.500000   27.500000                  0.243750   24.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   31.250000   32.000000                  0.372500   29.000000    0.000000
# ...

# %%
def sigmoid(z):
    return (1/(1+np.exp(-z)))

# %%
sigmoid(5)
# Out:
# 0.9933071490757153

# %%
sigmoid(1000)
# Out:
# 1.0

# %%
sigmoid(103747)
# Out:
# 1.0

# %%
sigmoid(-59279)
# Out:
# 0.0

# %%
df.Outcome.value_counts()/len(df)*100
# Out:
# Outcome
# 0    65.104167
# 1    34.895833
# Name: count, dtype: float64

# %%
# split the data
x  = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age
# 0            6      148             72             35     30.5  33.6                     0.627   50
# 1            1       85             66             29     30.5  26.6                     0.351   31
# 2            8      183             64             23     30.5  23.3                     0.672   32
# 3            1       89             66             23     94.0  28.1                     0.167   21
# 4            0      137             40             35    168.0  43.1                     2.288   33

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
sc_x = scaler.fit_transform(x)

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
# !pip install scikit-learn==1.2.0

# %%
# imbalance treatment
import imblearn
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler()
x_sam, y_sam = ros.fit_resample(x,y)
print('original data', y.value_counts())
print('after oversampling data', y_sam.value_counts())
# Out:
# original data Outcome
# 0    500
# 1    268
# Name: count, dtype: int64
# after oversampling data Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
# split the data into train test 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_sam,y_sam, test_size=0.25, random_state=101, stratify=y_sam)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (750, 8) (250, 8) (750,) (250,)

# %%
# building logistic regression
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression(multi_class = 'ovr') 
logit.fit(x_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
y_pred_train=logit.predict(x_train)
y_pred_test = logit.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
print(confusion_matrix(y_train, y_pred_train))
print('-------')
print(confusion_matrix(y_test, y_pred_test))
# Out:
# [[274 101]
#  [103 272]]
# -------
# [[94 31]
#  [39 86]]

# %%
print(classification_report(y_train, y_pred_train))
print('-------')
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73       375
#            1       0.73      0.73      0.73       375
#
#     accuracy                           0.73       750
#    macro avg       0.73      0.73      0.73       750
# weighted avg       0.73      0.73      0.73       750
#
# -------
#               precision    recall  f1-score   support
#
#            0       0.71      0.75      0.73       125
#            1       0.74      0.69      0.71       125
#
#     accuracy                           0.72       250
#    macro avg       0.72      0.72      0.72       250
# weighted avg       0.72      0.72      0.72       250

# %%
print("train",accuracy_score(y_train, y_pred_train))
print('-------')
print("test",accuracy_score(y_test, y_pred_test))
# Out:
# train 0.728
# -------
# test 0.72

# %% [markdown]
# # K-Fold method

# %%
from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(logit, x_train, y_train, cv=10)
print(accuracy)
print()
print(accuracy.mean())
print()
print(accuracy.max())
# Out:
# [0.73333333 0.73333333 0.73333333 0.72       0.78666667 0.77333333
#  0.74666667 0.78666667 0.62666667 0.74666667]
#
# 0.7386666666666668
#
# 0.7866666666666666

# %% [markdown]
# # ROC and AUC Curve

# %%
from sklearn.metrics import roc_auc_score
log_roc_auc = roc_auc_score(y_test, y_pred_test)
log_roc_auc
# Out:
# 0.72

# %%
from sklearn.metrics import roc_curve
fpr, tpr, threshold = roc_curve(y_test, y_pred_test)

plt.figure()
plt.plot(fpr,tpr, label = 'ROC Curve (%0.2f)' % log_roc_auc)
plt.plot([0,1],[0,1],'k--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('-----Receiver Operating Characteristic with Area Under Curve (ROC-AUC)-------')
plt.legend(loc = 'lower right')
plt.show()

# %%
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
logit = sm.LogisticRegression()
logit.fit(x_train,y_train)
logit.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 3
#       1 import statsmodels.api as sm
#       2 from sklearn.linear_model import LogisticRegression
# ----> 3 logit = sm.LogisticRegression()
#       4 logit.fit(x_train,y_train)
#       5 logit.summary()
#
# AttributeError: module 'statsmodels.api' has no attribute 'LogisticRegression'
